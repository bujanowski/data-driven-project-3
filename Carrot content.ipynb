# %%
import pandas as pd

# %% [markdown]
# Food in Russia as a whole has risen in price in the recent years. Many vegetables e.g. beets, cabbage, carrots and potatoes have become the leaders of growth.

# %% [markdown]
# Stats in this jn are from here https://www.fedstat.ru/indicator/31448

# %%
df = pd.read_excel("carrots.xls")

# %%
df.head()
# Out:
#   Средние потребительские цены (тарифы) на товары и услуги  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                        Морковь, кг
#
#              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                   NaN        NaN        NaN        NaN        NaN
# 1                   NaN        NaN       2016        NaN        NaN
# 2                   NaN        NaN     январь    февраль       март
# 3  Российская Федерация      рубль      32.29      33.71      34.11
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 58 Unnamed: 59  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2     апрель        май       июнь       июль  ...      август    сентябрь
# ...

# %%
df.rename(columns={'Средние потребительские цены (тарифы) на товары и услуги': 'Price'}, inplace=True)

# %%
df
# Out:
#          Price            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN                   NaN        NaN        NaN        NaN
# 1          NaN                   NaN        NaN       2016        NaN
# 2          NaN                   NaN        NaN     январь    февраль
# 3  Морковь, кг  Российская Федерация      рубль      32.29      33.71
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 58  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 2       март     апрель        май       июнь       июль  ...      август
# 3      34.11      36.25      39.34      41.88      39.58  ...       40.68
#
#   Unnamed: 59 Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN        2021         NaN
# ...

# %%
df = df.drop([0])

# %%
df
# Out:
#          Price            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 1          NaN                   NaN        NaN       2016        NaN
# 2          NaN                   NaN        NaN     январь    февраль
# 3  Морковь, кг  Российская Федерация      рубль      32.29      33.71
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 58  \
# 1        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 2       март     апрель        май       июнь       июль  ...      август
# 3      34.11      36.25      39.34      41.88      39.58  ...       40.68
#
#   Unnamed: 59 Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64  \
# 1         NaN         NaN         NaN         NaN        2021         NaN
# 2    сентябрь     октябрь      ноябрь     декабрь      январь     февраль
# 3       34.27       32.11       32.27       34.21       37.28       39.96
#
#   Unnamed: 65 Unnamed: 66 Unnamed: 67
# 1         NaN         NaN         NaN
# ...

# %%
df = df.drop(columns=['Unnamed: 1', 'Unnamed: 2'])

# %%
df
# Out:
#          Price Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 1          NaN       2016        NaN        NaN        NaN        NaN
# 2          NaN     январь    февраль       март     апрель        май
# 3  Морковь, кг      32.29      33.71      34.11      36.25      39.34
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  ... Unnamed: 58 Unnamed: 59  \
# 1        NaN        NaN         NaN         NaN  ...         NaN         NaN
# 2       июнь       июль      август    сентябрь  ...      август    сентябрь
# 3      41.88      39.58       32.86        26.9  ...       40.68       34.27
#
#   Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64 Unnamed: 65  \
# 1         NaN         NaN         NaN        2021         NaN         NaN
# 2     октябрь      ноябрь     декабрь      январь     февраль        март
# 3       32.11       32.27       34.21       37.28       39.96       45.75
#
#   Unnamed: 66 Unnamed: 67
# 1         NaN         NaN
# ...

# %%
df = df.T

# %%
df.columns = ['Year', 'Month', 'Carrots_price_per_kg']

# %%
df
# Out:
#              Year    Month Carrots_price_per_kg
# Price         NaN      NaN          Морковь, кг
# Unnamed: 3   2016   январь                32.29
# Unnamed: 4    NaN  февраль                33.71
# Unnamed: 5    NaN     март                34.11
# Unnamed: 6    NaN   апрель                36.25
# ...           ...      ...                  ...
# Unnamed: 63  2021   январь                37.28
# Unnamed: 64   NaN  февраль                39.96
# Unnamed: 65   NaN     март                45.75
# Unnamed: 66   NaN   апрель                50.05
# Unnamed: 67   NaN      май                59.47
#
# [66 rows x 3 columns]

# %%
df.reset_index()
# Out:
#           index  Year    Month Carrots_price_per_kg
# 0         Price   NaN      NaN          Морковь, кг
# 1    Unnamed: 3  2016   январь                32.29
# 2    Unnamed: 4   NaN  февраль                33.71
# 3    Unnamed: 5   NaN     март                34.11
# 4    Unnamed: 6   NaN   апрель                36.25
# ..          ...   ...      ...                  ...
# 61  Unnamed: 63  2021   январь                37.28
# 62  Unnamed: 64   NaN  февраль                39.96
# 63  Unnamed: 65   NaN     март                45.75
# 64  Unnamed: 66   NaN   апрель                50.05
# 65  Unnamed: 67   NaN      май                59.47
#
# [66 rows x 4 columns]

# %%
df = df.reset_index()

# %%
df = df.drop(columns=['index'])

# %%
df = df.drop([0])

# %%
df.head(25)
# Out:
#     Year     Month Carrots_price_per_kg
# 1   2016    январь                32.29
# 2    NaN   февраль                33.71
# 3    NaN      март                34.11
# 4    NaN    апрель                36.25
# 5    NaN       май                39.34
# 6    NaN      июнь                41.88
# 7    NaN      июль                39.58
# 8    NaN    август                32.86
# 9    NaN  сентябрь                 26.9
# 10   NaN   октябрь                25.85
# 11   NaN    ноябрь                25.75
# 12   NaN   декабрь                25.94
# 13  2017    январь                26.98
# 14   NaN   февраль                27.68
# 15   NaN      март                28.06
# 16   NaN    апрель                31.23
# 17   NaN       май                38.39
# 18   NaN      июнь                 47.2
# 19   NaN      июль                46.73
# 20   NaN    август                33.74
# 21   NaN  сентябрь                 27.7
# 22   NaN   октябрь                25.88
# ...

# %%
df = df.fillna(method='ffill')
#You can use pandas.DataFrame.fillna with the method='ffill' option. 'ffill' stands for 'forward fill' 
#and will propagate last valid observation forward. 
#The alternative is 'bfill' which works the same way, but backwards.

# %%
df.head(35)
# Out:
#     Year     Month  Carrots_price_per_kg
# 1   2016    январь                 32.29
# 2   2016   февраль                 33.71
# 3   2016      март                 34.11
# 4   2016    апрель                 36.25
# 5   2016       май                 39.34
# 6   2016      июнь                 41.88
# 7   2016      июль                 39.58
# 8   2016    август                 32.86
# 9   2016  сентябрь                 26.90
# 10  2016   октябрь                 25.85
# 11  2016    ноябрь                 25.75
# 12  2016   декабрь                 25.94
# 13  2017    январь                 26.98
# 14  2017   февраль                 27.68
# 15  2017      март                 28.06
# 16  2017    апрель                 31.23
# 17  2017       май                 38.39
# 18  2017      июнь                 47.20
# 19  2017      июль                 46.73
# 20  2017    август                 33.74
# 21  2017  сентябрь                 27.70
# 22  2017   октябрь                 25.88
# ...

# %%
#df = df.drop(columns=['Year'])

# %%
df
# Out:
#     Year    Month  Carrots_price_per_kg
# 1   2016   январь                 32.29
# 2   2016  февраль                 33.71
# 3   2016     март                 34.11
# 4   2016   апрель                 36.25
# 5   2016      май                 39.34
# ..   ...      ...                   ...
# 61  2021   январь                 37.28
# 62  2021  февраль                 39.96
# 63  2021     март                 45.75
# 64  2021   апрель                 50.05
# 65  2021      май                 59.47
#
# [65 rows x 3 columns]

# %%
#df['Month'].str.replace("январь", "January")

# %%
df = df.replace({'Month':{'январь':'January', 'февраль':'February', 'март':'March', 'апрель':'April', 'май':'May', 'июнь':'June', 'июль':'July', 'август':'August', 'сентябрь':'September', 'октябрь':'October', 'ноябрь':'November', 'декабрь':'December'}})

# %%
df.head(15)
# Out:
#     Year      Month  Carrots_price_per_kg
# 1   2016    January                 32.29
# 2   2016   February                 33.71
# 3   2016      March                 34.11
# 4   2016      April                 36.25
# 5   2016        May                 39.34
# 6   2016       June                 41.88
# 7   2016       July                 39.58
# 8   2016     August                 32.86
# 9   2016  September                 26.90
# 10  2016    October                 25.85
# 11  2016   November                 25.75
# 12  2016   December                 25.94
# 13  2017    January                 26.98
# 14  2017   February                 27.68
# 15  2017      March                 28.06

# %%
import matplotlib.pyplot as plot

# %%
! pip install emoji
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\evgeniya bujanowski\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
#haha

from emoji import emojize
print(emojize("\U0001f955"))
# Out:
# 🥕

# %%
df['Carrots_price_per_kg'].plot.line(color = 'orange').set_facecolor("white")
plot.title('Carrots are getting more expensive in Russia', fontsize = 14)
plot.xlabel("2016 - 2021")
plot.ylabel("Price for one kg carrots")
plot.savefig("carrots_before_Illustrator.pdf", transparent=True)

# %%
import matplotlib

# %%
#from Soma - http://jonathansoma.com/lede/data-studio/matplotlib/exporting-from-matplotlib-to-open-in-adobe-illustrator/
matplotlib.rcParams['pdf.fonttype'] = 42

# %%
matplotlib.rcParams['ps.fonttype'] = 42

# %%
plot.show()

# %% [markdown]
# cols ={"xx":"yy", "ss":"tt"})

# %% [markdown]
# df.rename(columns=cols, inplace=True)
